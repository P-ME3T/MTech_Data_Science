# %% [markdown]
# # Problem Statement:

# %% [markdown]
#  A company has thirteen existing factories with 600 to 3500 units of supply. Four of these factories will be closed and new factories with 5000 units of supply will be located in 2 of their 148 customer sites. Which existing factories should be closed, and which new sites should be selected to minimize total shipping costs if customer demand cannot be split between factories?

# %%
import pandas as pd
import numpy as np

# %%
supply=pd.read_csv(r"C:\Users\Admin\Desktop\Meet_M2_AOSC\QFolder\Factories.csv")
demand=pd.read_excel(r"C:\Users\Admin\Desktop\Meet_M2_AOSC\QFolder\Customers.xls")
location=pd.read_csv(r"C:\Users\Admin\Desktop\Meet_M2_AOSC\QFolder\Location_data.csv")
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %% [markdown]
# Problem consitute of 13 supply locations and 148 demand locations for the oil requirement throughout the globe. As unit cost for transportation is not mentioned in problem we have to assume 1 unit cost per unit area.

# %%
supply.shape, demand.shape, location.shape
# Out:
# ((13, 2), (148, 2), (161, 3))

# %% [markdown]
# cost matrix need to be computed using locations provided.

# %%
dist=np.zeros([13,148])

# %%
location=location.set_index('Location')
location.head()
# Out:
#                       LAT        LONG
# Location
# Birmingham, AL  33.524755   86.812740
# Mobile, AL      30.679523   88.103280
# Montgomery, AL  32.361538   86.279118
# Tuscaloosa, AL  33.206540   87.534607
# Anchorage, AK   61.191900  149.762097

# %%
supply.head()
# Out:
#       Location  Supply
# 0   Tucson, AZ    2000
# 1   Fresno, CA    2200
# 2  Lansing, MI    2600
# 3  Bozeman, MT     600
# 4     Reno, NV    2500

# %%
demand1=demand.T
demand1.head()
# Out:
#                      0           1               2               3    \
# Location  Birmingham, AL  Mobile, AL  Montgomery, AL  Tuscaloosa, AL
# Demand               200         100             150              50
#
#                     4              5           6              7    \
# Location  Anchorage, AK  Fairbanks, AK  Juneau, AK  Flagstaff, AZ
# Demand               50            100         200             50
#
#                   8               9    ...           138            139  \
# Location  Phoenix, AZ  Scottsdale, AZ  ...  Wheeling, WV  Green Bay, WI
# Demand            300             100  ...           150            150
#
#                   140            141          142         143           144  \
# Location  Madison, WI  Milwaukee, WI  Oshkosh, WI  Casper, WY  Cheyenne, WY
# Demand            250            300           50          50           150
#
#                145           146          147
# Location  Cody, WY  Evanston, WY  Laramie, WY
# Demand          50           150          100
#
# [2 rows x 148 columns]

# %% [markdown]
# ## Calculating Cost matrix

# %% [markdown]
# For every demand supply pair we have a unique cost associated which will help the transportation problem to minimize the cost according to it.
# Using the mathematical formula we have calculated minimum possible distance for every demand and supply point and assigned it as a cost for it.

# %%
from math import sin, cos, sqrt, atan2
R = 6373.0
cost_matrix=np.zeros([13,148])
for i in range (13):
    loc = supply.loc[i,'Location']
    lat1=location.loc[loc,'LAT']
    lon1 = location.loc[loc,'LONG']
    for j in range (148):
        loc2 = demand.loc[j,'Location']
        lat2=location.loc[loc2,'LAT']
        lon2 = location.loc[loc2,'LONG']
        dlon = lon2 - lon1
        dlat = lat2 - lat1
        a = (sin(dlat/2))**2 + cos(lat1) * cos(lat2) * (sin(dlon/2))**2
        c = 2 * atan2(sqrt(a), sqrt(1-a))
        distance = R * c
        cost_matrix[i][j]=distance

# %%
cost_matrix.shape
# Out:
# (13, 148)

# %%
cost_df=pd.DataFrame(cost_matrix)

# %%
cost_df
# Out:
#              0             1             2             3             4    \
# 0    7176.303947  16277.681570   2210.463543   4831.772243  15268.493586
# 1   14812.930047   1642.507130  16166.638206  16650.047526   4237.240711
# 2   15141.314073   7139.918317  15921.551724  16680.725592   1660.593315
# 3    2992.330867  14215.720547   4734.693259   1641.525465  18927.965069
# 4    3798.636615  16244.094127   3378.377635   1291.170964  18285.264195
# 5    3381.147334  16119.292421   8528.084708   4702.958703  13546.605449
# 6   16353.390298   5194.653556  16340.678883  18546.241961    324.575268
# 7    7506.588813  14907.369705    835.850220   4982.997040  15732.014332
# 8   16574.354014   5317.232597  16055.531783  18610.482676    423.455861
# 9    9447.583212  13394.319085   2389.876776   6915.472966  14001.667123
# 10   5411.663345   9560.635360  11527.434589   7560.970126  12104.029452
# 11  15467.864584   2855.351401  16875.348030  17748.152310   2850.321858
# 12  10968.854198   5292.154483  17182.979767  13376.879621   6253.978280
#
#              5             6             7             8             9    ...  \
# 0    6932.349178   5139.047439  16505.254143   6895.807971   7607.940159  ...
# 1   13189.304743  14916.871916   5728.517141  15166.532158  14429.113970  ...
# 2   18893.674823  19321.551401   5429.143275  14985.221415  14801.971637  ...
# 3    2448.300849   1742.341108  13426.236343   3109.821286   3370.195929  ...
# 4    4341.342175   2716.683412  14488.110093   3621.128121   4251.283731  ...
# 5    8292.702667   7541.561902   9398.845481   3055.432834   3290.597605  ...
# 6   17123.256546  18599.486470   5637.480790  16357.083184  15924.540201  ...
# 7    5980.949238   4320.432285  17865.951076   7318.173099   7959.308852  ...
# 8   17247.129869  18555.196481   5902.528175  16552.198699  16153.775287  ...
# 9    7165.906990   5782.434107  18892.353729   9270.168828   9900.971506  ...
# 10   6772.004703   8041.651814   6991.515502   5780.183880   5045.055313  ...
# 11  14583.466840  16308.945281   5262.057281  15736.422967  15033.006591  ...
# 12  12021.149710  13667.607384   2711.683655  11238.325989  10532.240615  ...
#
#              138           139           140           141           142  \
# 0    7963.719768  10047.641878  17955.557784  16024.164183  14255.686734
# 1   14350.619751   9448.366273   3860.291434   1608.755100   6191.641511
# 2   13352.687195  15222.684719   4359.368194   5986.158442  11544.026461
# 3    4757.357674   6246.635226  15039.268029  15529.593321   9043.442593
# 4    5067.570923   8155.496212  16464.106287  17331.485983  11360.296911
# 5    1919.992984  11596.501505  11399.678423  16577.842014  11608.663318
# 6   14719.114182  13288.184830   3920.983450   4006.305485  10045.065420
# 7    8656.517682   8685.872422  19414.228189  14961.864917  13069.024239
# 8   14903.231146  13396.936087   4207.669422   4085.383473  10274.158436
# 9   10602.126833   8927.254321  17864.033176  13170.884507  13389.054441
# 10   5446.631896   6759.834448   8237.278089  10734.292239   4533.580444
# 11  14535.390317  10836.684381   3245.641142   2108.231248   7480.732486
# 12  10179.892562   9655.201790   2582.193622   5806.849872   5173.067294
#
#              143           144           145           146           147
# 0   14839.476578  16752.581308   8742.509683  17613.555430  14829.886421
# 1    3166.521338   5288.475907  13669.987171   4267.878354   7403.158601
# 2    4618.641162   8488.064096  11835.111454   7992.081177   6005.589734
# 3   17224.043990  11158.678278   6265.720114  11911.154653  12467.055771
# 4   17882.696829  13184.590108   6315.244977  14050.284687  13070.826886
# 5   16603.121730  10133.054068   1453.404577  11154.207957   7793.735198
# 6    2773.095715   7762.689834  13278.978151   7020.215337   6754.064702
# 7   14307.442577  16417.708148   9687.873341  16902.188253  16194.348877
# 8    2707.707957   8051.838056  13441.985962   7302.724472   6982.708875
# 9   12354.645153  17402.133179  11566.767468  17240.914847  17531.059516
# 10  12569.185430   4371.945471   5803.132896   5262.042555   6830.032925
# 11   2590.230675   5875.659440  13515.012807   4945.046009   6845.508659
# 12   7072.987803   1577.527196   9493.640678   1220.356206   4136.245176
#
# [13 rows x 148 columns]

# %%
#cost_df['name']=supply['Location']

# %%
#cost_df.set_index('name')

# %%
cost_df.head(3)
# Out:
#             0             1             2             3             4    \
# 0   7176.303947  16277.681570   2210.463543   4831.772243  15268.493586
# 1  14812.930047   1642.507130  16166.638206  16650.047526   4237.240711
# 2  15141.314073   7139.918317  15921.551724  16680.725592   1660.593315
#
#             5             6             7             8             9    ...  \
# 0   6932.349178   5139.047439  16505.254143   6895.807971   7607.940159  ...
# 1  13189.304743  14916.871916   5728.517141  15166.532158  14429.113970  ...
# 2  18893.674823  19321.551401   5429.143275  14985.221415  14801.971637  ...
#
#             138           139           140           141           142  \
# 0   7963.719768  10047.641878  17955.557784  16024.164183  14255.686734
# 1  14350.619751   9448.366273   3860.291434   1608.755100   6191.641511
# 2  13352.687195  15222.684719   4359.368194   5986.158442  11544.026461
#
#             143           144           145           146           147
# 0  14839.476578  16752.581308   8742.509683  17613.555430  14829.886421
# 1   3166.521338   5288.475907  13669.987171   4267.878354   7403.158601
# 2   4618.641162   8488.064096  11835.111454   7992.081177   6005.589734
#
# [3 rows x 148 columns]

# %%
cost_df1=cost_df.T

# %%
cost_df1['name2']=demand['Location']

# %%
cost_df2=cost_df1.T
cost_df2
# Out:
#                   0           1               2               3    \
# 0              7176.3     16277.7         2210.46         4831.77
# 1             14812.9     1642.51         16166.6           16650
# 2             15141.3     7139.92         15921.6         16680.7
# 3             2992.33     14215.7         4734.69         1641.53
# 4             3798.64     16244.1         3378.38         1291.17
# 5             3381.15     16119.3         8528.08         4702.96
# 6             16353.4     5194.65         16340.7         18546.2
# 7             7506.59     14907.4          835.85            4983
# 8             16574.4     5317.23         16055.5         18610.5
# 9             9447.58     13394.3         2389.88         6915.47
# 10            5411.66     9560.64         11527.4         7560.97
# 11            15467.9     2855.35         16875.3         17748.2
# 12            10968.9     5292.15           17183         13376.9
# name2  Birmingham, AL  Mobile, AL  Montgomery, AL  Tuscaloosa, AL
#
#                  4              5           6              7            8    \
# 0            15268.5        6932.35     5139.05        16505.3      6895.81
# 1            4237.24        13189.3     14916.9        5728.52      15166.5
# 2            1660.59        18893.7     19321.6        5429.14      14985.2
# 3              18928         2448.3     1742.34        13426.2      3109.82
# 4            18285.3        4341.34     2716.68        14488.1      3621.13
# 5            13546.6         8292.7     7541.56        9398.85      3055.43
# 6            324.575        17123.3     18599.5        5637.48      16357.1
# 7              15732        5980.95     4320.43          17866      7318.17
# 8            423.456        17247.1     18555.2        5902.53      16552.2
# 9            14001.7        7165.91     5782.43        18892.4      9270.17
# 10             12104           6772     8041.65        6991.52      5780.18
# 11           2850.32        14583.5     16308.9        5262.06      15736.4
# 12           6253.98        12021.1     13667.6        2711.68      11238.3
# name2  Anchorage, AK  Fairbanks, AK  Juneau, AK  Flagstaff, AZ  Phoenix, AZ
#
#                   9    ...           138            139          140  \
# 0             7607.94  ...       7963.72        10047.6      17955.6
# 1             14429.1  ...       14350.6        9448.37      3860.29
# 2               14802  ...       13352.7        15222.7      4359.37
# 3              3370.2  ...       4757.36        6246.64      15039.3
# 4             4251.28  ...       5067.57         8155.5      16464.1
# 5              3290.6  ...       1919.99        11596.5      11399.7
# 6             15924.5  ...       14719.1        13288.2      3920.98
# 7             7959.31  ...       8656.52        8685.87      19414.2
# 8             16153.8  ...       14903.2        13396.9      4207.67
# 9             9900.97  ...       10602.1        8927.25        17864
# 10            5045.06  ...       5446.63        6759.83      8237.28
# 11              15033  ...       14535.4        10836.7      3245.64
# 12            10532.2  ...       10179.9         9655.2      2582.19
# name2  Scottsdale, AZ  ...  Wheeling, WV  Green Bay, WI  Madison, WI
#
#                  141          142         143           144       145  \
# 0            16024.2      14255.7     14839.5       16752.6   8742.51
# 1            1608.76      6191.64     3166.52       5288.48     13670
# 2            5986.16        11544     4618.64       8488.06   11835.1
# 3            15529.6      9043.44       17224       11158.7   6265.72
# 4            17331.5      11360.3     17882.7       13184.6   6315.24
# 5            16577.8      11608.7     16603.1       10133.1    1453.4
# 6            4006.31      10045.1      2773.1       7762.69     13279
# 7            14961.9        13069     14307.4       16417.7   9687.87
# 8            4085.38      10274.2     2707.71       8051.84     13442
# 9            13170.9      13389.1     12354.6       17402.1   11566.8
# 10           10734.3      4533.58     12569.2       4371.95   5803.13
# 11           2108.23      7480.73     2590.23       5875.66     13515
# 12           5806.85      5173.07     7072.99       1577.53   9493.64
# name2  Milwaukee, WI  Oshkosh, WI  Casper, WY  Cheyenne, WY  Cody, WY
#
#                 146          147
# 0           17613.6      14829.9
# 1           4267.88      7403.16
# 2           7992.08      6005.59
# 3           11911.2      12467.1
# 4           14050.3      13070.8
# 5           11154.2      7793.74
# 6           7020.22      6754.06
# 7           16902.2      16194.3
# 8           7302.72      6982.71
# 9           17240.9      17531.1
# 10          5262.04      6830.03
# 11          4945.05      6845.51
# 12          1220.36      4136.25
# name2  Evanston, WY  Laramie, WY
#
# [14 rows x 148 columns]

# %%
#cost_df2['name2']

# %%
cost_df2.columns = cost_df2.loc['name2']

# %%
cost_df2.head(5)
# Out:
# name2 Birmingham, AL Mobile, AL Montgomery, AL Tuscaloosa, AL Anchorage, AK  \
# 0             7176.3    16277.7        2210.46        4831.77       15268.5
# 1            14812.9    1642.51        16166.6          16650       4237.24
# 2            15141.3    7139.92        15921.6        16680.7       1660.59
# 3            2992.33    14215.7        4734.69        1641.53         18928
# 4            3798.64    16244.1        3378.38        1291.17       18285.3
#
# name2 Fairbanks, AK Juneau, AK Flagstaff, AZ Phoenix, AZ Scottsdale, AZ  ...  \
# 0           6932.35    5139.05       16505.3     6895.81        7607.94  ...
# 1           13189.3    14916.9       5728.52     15166.5        14429.1  ...
# 2           18893.7    19321.6       5429.14     14985.2          14802  ...
# 3            2448.3    1742.34       13426.2     3109.82         3370.2  ...
# 4           4341.34    2716.68       14488.1     3621.13        4251.28  ...
#
# name2 Wheeling, WV Green Bay, WI Madison, WI Milwaukee, WI Oshkosh, WI  \
# 0          7963.72       10047.6     17955.6       16024.2     14255.7
# 1          14350.6       9448.37     3860.29       1608.76     6191.64
# 2          13352.7       15222.7     4359.37       5986.16       11544
# 3          4757.36       6246.64     15039.3       15529.6     9043.44
# 4          5067.57        8155.5     16464.1       17331.5     11360.3
#
# name2 Casper, WY Cheyenne, WY Cody, WY Evanston, WY Laramie, WY
# 0        14839.5      16752.6  8742.51      17613.6     14829.9
# 1        3166.52      5288.48    13670      4267.88     7403.16
# 2        4618.64      8488.06  11835.1      7992.08     6005.59
# 3          17224      11158.7  6265.72      11911.2     12467.1
# 4        17882.7      13184.6  6315.24      14050.3     13070.8
#
# [5 rows x 148 columns]

# %%
cost_df2['name']=supply['Location']
cost_df=cost_df2.set_index('name')
cost_df
# Out:
# name2           Birmingham, AL  Mobile, AL  Montgomery, AL  Tuscaloosa, AL  \
# name
# Tucson, AZ              7176.3     16277.7         2210.46         4831.77
# Fresno, CA             14812.9     1642.51         16166.6           16650
# Lansing, MI            15141.3     7139.92         15921.6         16680.7
# Bozeman, MT            2992.33     14215.7         4734.69         1641.53
# Reno, NV               3798.64     16244.1         3378.38         1291.17
# Trenton, NJ            3381.15     16119.3         8528.08         4702.96
# Greensboro, NC         16353.4     5194.65         16340.7         18546.2
# Columbus, OH           7506.59     14907.4          835.85            4983
# Tulsa, OK              16574.4     5317.23         16055.5         18610.5
# Harrisburg, PA         9447.58     13394.3         2389.88         6915.47
# Florence, SC           5411.66     9560.64         11527.4         7560.97
# Bristol, TN            15467.9     2855.35         16875.3         17748.2
# Spokane, WA            10968.9     5292.15           17183         13376.9
# NaN             Birmingham, AL  Mobile, AL  Montgomery, AL  Tuscaloosa, AL
#
# name2           Anchorage, AK  Fairbanks, AK  Juneau, AK  Flagstaff, AZ  \
# name
# Tucson, AZ            15268.5        6932.35     5139.05        16505.3
# Fresno, CA            4237.24        13189.3     14916.9        5728.52
# Lansing, MI           1660.59        18893.7     19321.6        5429.14
# Bozeman, MT             18928         2448.3     1742.34        13426.2
# Reno, NV              18285.3        4341.34     2716.68        14488.1
# Trenton, NJ           13546.6         8292.7     7541.56        9398.85
# Greensboro, NC        324.575        17123.3     18599.5        5637.48
# Columbus, OH            15732        5980.95     4320.43          17866
# Tulsa, OK             423.456        17247.1     18555.2        5902.53
# Harrisburg, PA        14001.7        7165.91     5782.43        18892.4
# Florence, SC            12104           6772     8041.65        6991.52
# Bristol, TN           2850.32        14583.5     16308.9        5262.06
# Spokane, WA           6253.98        12021.1     13667.6        2711.68
# NaN             Anchorage, AK  Fairbanks, AK  Juneau, AK  Flagstaff, AZ
#
# name2           Phoenix, AZ  Scottsdale, AZ  ...  Wheeling, WV  Green Bay, WI  \
# name                                         ...
# Tucson, AZ          6895.81         7607.94  ...       7963.72        10047.6
# Fresno, CA          15166.5         14429.1  ...       14350.6        9448.37
# Lansing, MI         14985.2           14802  ...       13352.7        15222.7
# Bozeman, MT         3109.82          3370.2  ...       4757.36        6246.64
# Reno, NV            3621.13         4251.28  ...       5067.57         8155.5
# Trenton, NJ         3055.43          3290.6  ...       1919.99        11596.5
# Greensboro, NC      16357.1         15924.5  ...       14719.1        13288.2
# Columbus, OH        7318.17         7959.31  ...       8656.52        8685.87
# Tulsa, OK           16552.2         16153.8  ...       14903.2        13396.9
# Harrisburg, PA      9270.17         9900.97  ...       10602.1        8927.25
# Florence, SC        5780.18         5045.06  ...       5446.63        6759.83
# Bristol, TN         15736.4           15033  ...       14535.4        10836.7
# Spokane, WA         11238.3         10532.2  ...       10179.9         9655.2
# NaN             Phoenix, AZ  Scottsdale, AZ  ...  Wheeling, WV  Green Bay, WI
#
# name2           Madison, WI  Milwaukee, WI  Oshkosh, WI  Casper, WY  \
# name
# Tucson, AZ          17955.6        16024.2      14255.7     14839.5
# Fresno, CA          3860.29        1608.76      6191.64     3166.52
# Lansing, MI         4359.37        5986.16        11544     4618.64
# Bozeman, MT         15039.3        15529.6      9043.44       17224
# Reno, NV            16464.1        17331.5      11360.3     17882.7
# Trenton, NJ         11399.7        16577.8      11608.7     16603.1
# Greensboro, NC      3920.98        4006.31      10045.1      2773.1
# Columbus, OH        19414.2        14961.9        13069     14307.4
# Tulsa, OK           4207.67        4085.38      10274.2     2707.71
# Harrisburg, PA        17864        13170.9      13389.1     12354.6
# Florence, SC        8237.28        10734.3      4533.58     12569.2
# Bristol, TN         3245.64        2108.23      7480.73     2590.23
# Spokane, WA         2582.19        5806.85      5173.07     7072.99
# NaN             Madison, WI  Milwaukee, WI  Oshkosh, WI  Casper, WY
#
# name2           Cheyenne, WY  Cody, WY  Evanston, WY  Laramie, WY
# name
# Tucson, AZ           16752.6   8742.51       17613.6      14829.9
# Fresno, CA           5288.48     13670       4267.88      7403.16
# Lansing, MI          8488.06   11835.1       7992.08      6005.59
# Bozeman, MT          11158.7   6265.72       11911.2      12467.1
# Reno, NV             13184.6   6315.24       14050.3      13070.8
# Trenton, NJ          10133.1    1453.4       11154.2      7793.74
# Greensboro, NC       7762.69     13279       7020.22      6754.06
# Columbus, OH         16417.7   9687.87       16902.2      16194.3
# Tulsa, OK            8051.84     13442       7302.72      6982.71
# Harrisburg, PA       17402.1   11566.8       17240.9      17531.1
# Florence, SC         4371.95   5803.13       5262.04      6830.03
# Bristol, TN          5875.66     13515       4945.05      6845.51
# Spokane, WA          1577.53   9493.64       1220.36      4136.25
# NaN             Cheyenne, WY  Cody, WY  Evanston, WY  Laramie, WY
#
# [14 rows x 148 columns]

# %%
#cost_df.drop(index='NaN',axis=0)
cost_df = cost_df.iloc[:12,:]
cost_df.head()
# Out:
# name2       Birmingham, AL Mobile, AL Montgomery, AL Tuscaloosa, AL  \
# name
# Tucson, AZ          7176.3    16277.7        2210.46        4831.77
# Fresno, CA         14812.9    1642.51        16166.6          16650
# Lansing, MI        15141.3    7139.92        15921.6        16680.7
# Bozeman, MT        2992.33    14215.7        4734.69        1641.53
# Reno, NV           3798.64    16244.1        3378.38        1291.17
#
# name2       Anchorage, AK Fairbanks, AK Juneau, AK Flagstaff, AZ Phoenix, AZ  \
# name
# Tucson, AZ        15268.5       6932.35    5139.05       16505.3     6895.81
# Fresno, CA        4237.24       13189.3    14916.9       5728.52     15166.5
# Lansing, MI       1660.59       18893.7    19321.6       5429.14     14985.2
# Bozeman, MT         18928        2448.3    1742.34       13426.2     3109.82
# Reno, NV          18285.3       4341.34    2716.68       14488.1     3621.13
#
# name2       Scottsdale, AZ  ... Wheeling, WV Green Bay, WI Madison, WI  \
# name                        ...
# Tucson, AZ         7607.94  ...      7963.72       10047.6     17955.6
# Fresno, CA         14429.1  ...      14350.6       9448.37     3860.29
# Lansing, MI          14802  ...      13352.7       15222.7     4359.37
# Bozeman, MT         3370.2  ...      4757.36       6246.64     15039.3
# Reno, NV           4251.28  ...      5067.57        8155.5     16464.1
#
# name2       Milwaukee, WI Oshkosh, WI Casper, WY Cheyenne, WY Cody, WY  \
# name
# Tucson, AZ        16024.2     14255.7    14839.5      16752.6  8742.51
# Fresno, CA        1608.76     6191.64    3166.52      5288.48    13670
# Lansing, MI       5986.16       11544    4618.64      8488.06  11835.1
# Bozeman, MT       15529.6     9043.44      17224      11158.7  6265.72
# Reno, NV          17331.5     11360.3    17882.7      13184.6  6315.24
#
# name2       Evanston, WY Laramie, WY
# name
# Tucson, AZ       17613.6     14829.9
# Fresno, CA       4267.88     7403.16
# Lansing, MI      7992.08     6005.59
# Bozeman, MT      11911.2     12467.1
# Reno, NV         14050.3     13070.8
#
# [5 rows x 148 columns]

# %% [markdown]
# ## Calculating rowwise and columnwise sums.

# %%
#suppliers 
cost_df.sum(axis=1).sort_values(ascending=False)
# Out:
# name
# Bristol, TN       1.531214e+06
# Fresno, CA        1.530199e+06
# Tulsa, OK         1.528918e+06
# Greensboro, NC    1.527722e+06
# Harrisburg, PA    1.507638e+06
# Lansing, MI       1.506433e+06
# Columbus, OH      1.477464e+06
# Tucson, AZ        1.468509e+06
# Bozeman, MT       1.430981e+06
# Reno, NV          1.427841e+06
# Florence, SC      1.419308e+06
# Trenton, NJ       1.386610e+06
# dtype: float64

# %%
#demand 
cost_df.sum(axis=0).sort_values(ascending=True)
# Out:
# name2
# Paris, TX           113562.595166
# Louisville, KY      114244.491944
# Columbia, SC        114643.188792
# Miami, FL           114819.478738
# Montgomery, AL      114964.529356
#                         ...
# Flagstaff, AZ       125527.993030
# Evanston, WY        125662.293733
# Madison, WI         125968.103620
# Danbury, CT         127120.195552
# Newport News, VA    127132.470656
# Length: 148, dtype: float64

# %% [markdown]
# ## Modifying supply datasets

# %%
supply=supply.drop(index=[11,1,8,6],axis=0)

# %%
supply.loc[13,"Location"]="Paris, TX"
supply.loc[14,"Location"]="Louisville, KY"
supply.loc[13:14,"Supply"]=5000

# %%
supply=supply.reset_index()

# %%
supply=supply.drop('index',axis=1)
supply
# Out:
#           Location  Supply
# 0       Tucson, AZ  2000.0
# 1      Lansing, MI  2600.0
# 2      Bozeman, MT   600.0
# 3         Reno, NV  2500.0
# 4      Trenton, NJ  3500.0
# 5     Columbus, OH  2200.0
# 6   Harrisburg, PA  2500.0
# 7     Florence, SC  2500.0
# 8      Spokane, WA  3000.0
# 9        Paris, TX  5000.0
# 10  Louisville, KY  5000.0

# %% [markdown]
# ### New cost matrix

# %%
from math import sin, cos, sqrt, atan2
R = 6373.0
new_cost_matrix=np.zeros([11,148])
for i in range (11):
    loc = supply.loc[i,'Location']
    lat1=location.loc[loc,'LAT']
    lon1 = location.loc[loc,'LONG']
    for j in range (148):
        loc2 = demand.loc[j,'Location']
        lat2=location.loc[loc2,'LAT']
        lon2 = location.loc[loc2,'LONG']
        dlon = lon2 - lon1
        dlat = lat2 - lat1
        a = (sin(dlat/2))**2 + cos(lat1) * cos(lat2) * (sin(dlon/2))**2
        c = 2 * atan2(sqrt(a), sqrt(1-a))
        distance = R * c
        new_cost_matrix[i][j]=distance

# %%
new_cost_df=pd.DataFrame(new_cost_matrix)

# %%
new_cost_df
# Out:
#              0             1             2             3             4    \
# 0    7176.303947  16277.681570   2210.463543   4831.772243  15268.493586
# 1   15141.314073   7139.918317  15921.551724  16680.725592   1660.593315
# 2    2992.330867  14215.720547   4734.693259   1641.525465  18927.965069
# 3    3798.636615  16244.094127   3378.377635   1291.170964  18285.264195
# 4    3381.147334  16119.292421   8528.084708   4702.958703  13546.605449
# 5    7506.588813  14907.369705    835.850220   4982.997040  15732.014332
# 6    9447.583212  13394.319085   2389.876776   6915.472966  14001.667123
# 7    5411.663345   9560.635360  11527.434589   7560.970126  12104.029452
# 8   10968.854198   5292.154483  17182.979767  13376.879621   6253.978280
# 9    7229.119471  15029.144614    682.978312   4703.111363  16008.649685
# 10   8603.674482  15819.010654   3588.784076   6426.824793  13546.566128
#
#              5             6             7             8             9    ...  \
# 0    6932.349178   5139.047439  16505.254143   6895.807971   7607.940159  ...
# 1   18893.674823  19321.551401   5429.143275  14985.221415  14801.971637  ...
# 2    2448.300849   1742.341108  13426.236343   3109.821286   3370.195929  ...
# 3    4341.342175   2716.683412  14488.110093   3621.128121   4251.283731  ...
# 4    8292.702667   7541.561902   9398.845481   3055.432834   3290.597605  ...
# 5    5980.949238   4320.432285  17865.951076   7318.173099   7959.308852  ...
# 6    7165.906990   5782.434107  18892.353729   9270.168828   9900.971506  ...
# 7    6772.004703   8041.651814   6991.515502   5780.183880   5045.055313  ...
# 8   12021.149710  13667.607384   2711.683655  11238.325989  10532.240615  ...
# 9    5758.360728   4072.898021  17678.582238   7045.366882   7682.087723  ...
# 10   8601.551963   6831.346639  16015.474928   8272.905569   9007.206058  ...
#
#              138           139           140           141           142  \
# 0    7963.719768  10047.641878  17955.557784  16024.164183  14255.686734
# 1   13352.687195  15222.684719   4359.368194   5986.158442  11544.026461
# 2    4757.357674   6246.635226  15039.268029  15529.593321   9043.442593
# 3    5067.570923   8155.496212  16464.106287  17331.485983  11360.296911
# 4    1919.992984  11596.501505  11399.678423  16577.842014  11608.663318
# 5    8656.517682   8685.872422  19414.228189  14961.864917  13069.024239
# 6   10602.126833   8927.254321  17864.033176  13170.884507  13389.054441
# 7    5446.631896   6759.834448   8237.278089  10734.292239   4533.580444
# 8   10179.892562   9655.201790   2582.193622   5806.849872   5173.067294
# 9    8399.889040   8567.797367  19500.205403  15155.512020  12909.552414
# 10   9075.409079  11429.384428  16652.131579  15054.094292  15828.657253
#
#              143           144           145           146           147
# 0   14839.476578  16752.581308   8742.509683  17613.555430  14829.886421
# 1    4618.641162   8488.064096  11835.111454   7992.081177   6005.589734
# 2   17224.043990  11158.678278   6265.720114  11911.154653  12467.055771
# 3   17882.696829  13184.590108   6315.244977  14050.284687  13070.826886
# 4   16603.121730  10133.054068   1453.404577  11154.207957   7793.735198
# 5   14307.442577  16417.708148   9687.873341  16902.188253  16194.348877
# 6   12354.645153  17402.133179  11566.767468  17240.914847  17531.059516
# 7   12569.185430   4371.945471   5803.132896   5262.042555   6830.032925
# 8    7072.987803   1577.527196   9493.640678   1220.356206   4136.245176
# 9   14568.847739  16162.354602   9456.514354  16690.294545  16027.240004
# 10  13462.391337  18165.969004   9538.168615  19194.623227  14542.787409
#
# [11 rows x 148 columns]

# %%
new_cost_df1=new_cost_df.T

# %%
new_cost_df1['name2']=demand['Location']

# %%
new_cost_df2=new_cost_df1.T
new_cost_df2
# Out:
#                   0           1               2               3    \
# 0              7176.3     16277.7         2210.46         4831.77
# 1             15141.3     7139.92         15921.6         16680.7
# 2             2992.33     14215.7         4734.69         1641.53
# 3             3798.64     16244.1         3378.38         1291.17
# 4             3381.15     16119.3         8528.08         4702.96
# 5             7506.59     14907.4          835.85            4983
# 6             9447.58     13394.3         2389.88         6915.47
# 7             5411.66     9560.64         11527.4         7560.97
# 8             10968.9     5292.15           17183         13376.9
# 9             7229.12     15029.1         682.978         4703.11
# 10            8603.67       15819         3588.78         6426.82
# name2  Birmingham, AL  Mobile, AL  Montgomery, AL  Tuscaloosa, AL
#
#                  4              5           6              7            8    \
# 0            15268.5        6932.35     5139.05        16505.3      6895.81
# 1            1660.59        18893.7     19321.6        5429.14      14985.2
# 2              18928         2448.3     1742.34        13426.2      3109.82
# 3            18285.3        4341.34     2716.68        14488.1      3621.13
# 4            13546.6         8292.7     7541.56        9398.85      3055.43
# 5              15732        5980.95     4320.43          17866      7318.17
# 6            14001.7        7165.91     5782.43        18892.4      9270.17
# 7              12104           6772     8041.65        6991.52      5780.18
# 8            6253.98        12021.1     13667.6        2711.68      11238.3
# 9            16008.6        5758.36      4072.9        17678.6      7045.37
# 10           13546.6        8601.55     6831.35        16015.5      8272.91
# name2  Anchorage, AK  Fairbanks, AK  Juneau, AK  Flagstaff, AZ  Phoenix, AZ
#
#                   9    ...           138            139          140  \
# 0             7607.94  ...       7963.72        10047.6      17955.6
# 1               14802  ...       13352.7        15222.7      4359.37
# 2              3370.2  ...       4757.36        6246.64      15039.3
# 3             4251.28  ...       5067.57         8155.5      16464.1
# 4              3290.6  ...       1919.99        11596.5      11399.7
# 5             7959.31  ...       8656.52        8685.87      19414.2
# 6             9900.97  ...       10602.1        8927.25        17864
# 7             5045.06  ...       5446.63        6759.83      8237.28
# 8             10532.2  ...       10179.9         9655.2      2582.19
# 9             7682.09  ...       8399.89         8567.8      19500.2
# 10            9007.21  ...       9075.41        11429.4      16652.1
# name2  Scottsdale, AZ  ...  Wheeling, WV  Green Bay, WI  Madison, WI
#
#                  141          142         143           144       145  \
# 0            16024.2      14255.7     14839.5       16752.6   8742.51
# 1            5986.16        11544     4618.64       8488.06   11835.1
# 2            15529.6      9043.44       17224       11158.7   6265.72
# 3            17331.5      11360.3     17882.7       13184.6   6315.24
# 4            16577.8      11608.7     16603.1       10133.1    1453.4
# 5            14961.9        13069     14307.4       16417.7   9687.87
# 6            13170.9      13389.1     12354.6       17402.1   11566.8
# 7            10734.3      4533.58     12569.2       4371.95   5803.13
# 8            5806.85      5173.07     7072.99       1577.53   9493.64
# 9            15155.5      12909.6     14568.8       16162.4   9456.51
# 10           15054.1      15828.7     13462.4         18166   9538.17
# name2  Milwaukee, WI  Oshkosh, WI  Casper, WY  Cheyenne, WY  Cody, WY
#
#                 146          147
# 0           17613.6      14829.9
# 1           7992.08      6005.59
# 2           11911.2      12467.1
# 3           14050.3      13070.8
# 4           11154.2      7793.74
# 5           16902.2      16194.3
# 6           17240.9      17531.1
# 7           5262.04      6830.03
# 8           1220.36      4136.25
# 9           16690.3      16027.2
# 10          19194.6      14542.8
# name2  Evanston, WY  Laramie, WY
#
# [12 rows x 148 columns]

# %%
new_cost_df2.columns = new_cost_df2.loc['name2']

# %%
new_cost_df2.head(5)
# Out:
# name2 Birmingham, AL Mobile, AL Montgomery, AL Tuscaloosa, AL Anchorage, AK  \
# 0             7176.3    16277.7        2210.46        4831.77       15268.5
# 1            15141.3    7139.92        15921.6        16680.7       1660.59
# 2            2992.33    14215.7        4734.69        1641.53         18928
# 3            3798.64    16244.1        3378.38        1291.17       18285.3
# 4            3381.15    16119.3        8528.08        4702.96       13546.6
#
# name2 Fairbanks, AK Juneau, AK Flagstaff, AZ Phoenix, AZ Scottsdale, AZ  ...  \
# 0           6932.35    5139.05       16505.3     6895.81        7607.94  ...
# 1           18893.7    19321.6       5429.14     14985.2          14802  ...
# 2            2448.3    1742.34       13426.2     3109.82         3370.2  ...
# 3           4341.34    2716.68       14488.1     3621.13        4251.28  ...
# 4            8292.7    7541.56       9398.85     3055.43         3290.6  ...
#
# name2 Wheeling, WV Green Bay, WI Madison, WI Milwaukee, WI Oshkosh, WI  \
# 0          7963.72       10047.6     17955.6       16024.2     14255.7
# 1          13352.7       15222.7     4359.37       5986.16       11544
# 2          4757.36       6246.64     15039.3       15529.6     9043.44
# 3          5067.57        8155.5     16464.1       17331.5     11360.3
# 4          1919.99       11596.5     11399.7       16577.8     11608.7
#
# name2 Casper, WY Cheyenne, WY Cody, WY Evanston, WY Laramie, WY
# 0        14839.5      16752.6  8742.51      17613.6     14829.9
# 1        4618.64      8488.06  11835.1      7992.08     6005.59
# 2          17224      11158.7  6265.72      11911.2     12467.1
# 3        17882.7      13184.6  6315.24      14050.3     13070.8
# 4        16603.1      10133.1   1453.4      11154.2     7793.74
#
# [5 rows x 148 columns]

# %%
new_cost_df2['name']=supply['Location']
new_cost_df=new_cost_df2.set_index('name')
new_cost_df
# Out:
# name2           Birmingham, AL  Mobile, AL  Montgomery, AL  Tuscaloosa, AL  \
# name
# Tucson, AZ              7176.3     16277.7         2210.46         4831.77
# Lansing, MI            15141.3     7139.92         15921.6         16680.7
# Bozeman, MT            2992.33     14215.7         4734.69         1641.53
# Reno, NV               3798.64     16244.1         3378.38         1291.17
# Trenton, NJ            3381.15     16119.3         8528.08         4702.96
# Columbus, OH           7506.59     14907.4          835.85            4983
# Harrisburg, PA         9447.58     13394.3         2389.88         6915.47
# Florence, SC           5411.66     9560.64         11527.4         7560.97
# Spokane, WA            10968.9     5292.15           17183         13376.9
# Paris, TX              7229.12     15029.1         682.978         4703.11
# Louisville, KY         8603.67       15819         3588.78         6426.82
# NaN             Birmingham, AL  Mobile, AL  Montgomery, AL  Tuscaloosa, AL
#
# name2           Anchorage, AK  Fairbanks, AK  Juneau, AK  Flagstaff, AZ  \
# name
# Tucson, AZ            15268.5        6932.35     5139.05        16505.3
# Lansing, MI           1660.59        18893.7     19321.6        5429.14
# Bozeman, MT             18928         2448.3     1742.34        13426.2
# Reno, NV              18285.3        4341.34     2716.68        14488.1
# Trenton, NJ           13546.6         8292.7     7541.56        9398.85
# Columbus, OH            15732        5980.95     4320.43          17866
# Harrisburg, PA        14001.7        7165.91     5782.43        18892.4
# Florence, SC            12104           6772     8041.65        6991.52
# Spokane, WA           6253.98        12021.1     13667.6        2711.68
# Paris, TX             16008.6        5758.36      4072.9        17678.6
# Louisville, KY        13546.6        8601.55     6831.35        16015.5
# NaN             Anchorage, AK  Fairbanks, AK  Juneau, AK  Flagstaff, AZ
#
# name2           Phoenix, AZ  Scottsdale, AZ  ...  Wheeling, WV  Green Bay, WI  \
# name                                         ...
# Tucson, AZ          6895.81         7607.94  ...       7963.72        10047.6
# Lansing, MI         14985.2           14802  ...       13352.7        15222.7
# Bozeman, MT         3109.82          3370.2  ...       4757.36        6246.64
# Reno, NV            3621.13         4251.28  ...       5067.57         8155.5
# Trenton, NJ         3055.43          3290.6  ...       1919.99        11596.5
# Columbus, OH        7318.17         7959.31  ...       8656.52        8685.87
# Harrisburg, PA      9270.17         9900.97  ...       10602.1        8927.25
# Florence, SC        5780.18         5045.06  ...       5446.63        6759.83
# Spokane, WA         11238.3         10532.2  ...       10179.9         9655.2
# Paris, TX           7045.37         7682.09  ...       8399.89         8567.8
# Louisville, KY      8272.91         9007.21  ...       9075.41        11429.4
# NaN             Phoenix, AZ  Scottsdale, AZ  ...  Wheeling, WV  Green Bay, WI
#
# name2           Madison, WI  Milwaukee, WI  Oshkosh, WI  Casper, WY  \
# name
# Tucson, AZ          17955.6        16024.2      14255.7     14839.5
# Lansing, MI         4359.37        5986.16        11544     4618.64
# Bozeman, MT         15039.3        15529.6      9043.44       17224
# Reno, NV            16464.1        17331.5      11360.3     17882.7
# Trenton, NJ         11399.7        16577.8      11608.7     16603.1
# Columbus, OH        19414.2        14961.9        13069     14307.4
# Harrisburg, PA        17864        13170.9      13389.1     12354.6
# Florence, SC        8237.28        10734.3      4533.58     12569.2
# Spokane, WA         2582.19        5806.85      5173.07     7072.99
# Paris, TX           19500.2        15155.5      12909.6     14568.8
# Louisville, KY      16652.1        15054.1      15828.7     13462.4
# NaN             Madison, WI  Milwaukee, WI  Oshkosh, WI  Casper, WY
#
# name2           Cheyenne, WY  Cody, WY  Evanston, WY  Laramie, WY
# name
# Tucson, AZ           16752.6   8742.51       17613.6      14829.9
# Lansing, MI          8488.06   11835.1       7992.08      6005.59
# Bozeman, MT          11158.7   6265.72       11911.2      12467.1
# Reno, NV             13184.6   6315.24       14050.3      13070.8
# Trenton, NJ          10133.1    1453.4       11154.2      7793.74
# Columbus, OH         16417.7   9687.87       16902.2      16194.3
# Harrisburg, PA       17402.1   11566.8       17240.9      17531.1
# Florence, SC         4371.95   5803.13       5262.04      6830.03
# Spokane, WA          1577.53   9493.64       1220.36      4136.25
# Paris, TX            16162.4   9456.51       16690.3      16027.2
# Louisville, KY         18166   9538.17       19194.6      14542.8
# NaN             Cheyenne, WY  Cody, WY  Evanston, WY  Laramie, WY
#
# [12 rows x 148 columns]

# %%
new_cost_df = new_cost_df.iloc[:12,:]
new_cost_df.head()
# Out:
# name2       Birmingham, AL Mobile, AL Montgomery, AL Tuscaloosa, AL  \
# name
# Tucson, AZ          7176.3    16277.7        2210.46        4831.77
# Lansing, MI        15141.3    7139.92        15921.6        16680.7
# Bozeman, MT        2992.33    14215.7        4734.69        1641.53
# Reno, NV           3798.64    16244.1        3378.38        1291.17
# Trenton, NJ        3381.15    16119.3        8528.08        4702.96
#
# name2       Anchorage, AK Fairbanks, AK Juneau, AK Flagstaff, AZ Phoenix, AZ  \
# name
# Tucson, AZ        15268.5       6932.35    5139.05       16505.3     6895.81
# Lansing, MI       1660.59       18893.7    19321.6       5429.14     14985.2
# Bozeman, MT         18928        2448.3    1742.34       13426.2     3109.82
# Reno, NV          18285.3       4341.34    2716.68       14488.1     3621.13
# Trenton, NJ       13546.6        8292.7    7541.56       9398.85     3055.43
#
# name2       Scottsdale, AZ  ... Wheeling, WV Green Bay, WI Madison, WI  \
# name                        ...
# Tucson, AZ         7607.94  ...      7963.72       10047.6     17955.6
# Lansing, MI          14802  ...      13352.7       15222.7     4359.37
# Bozeman, MT         3370.2  ...      4757.36       6246.64     15039.3
# Reno, NV           4251.28  ...      5067.57        8155.5     16464.1
# Trenton, NJ         3290.6  ...      1919.99       11596.5     11399.7
#
# name2       Milwaukee, WI Oshkosh, WI Casper, WY Cheyenne, WY Cody, WY  \
# name
# Tucson, AZ        16024.2     14255.7    14839.5      16752.6  8742.51
# Lansing, MI       5986.16       11544    4618.64      8488.06  11835.1
# Bozeman, MT       15529.6     9043.44      17224      11158.7  6265.72
# Reno, NV          17331.5     11360.3    17882.7      13184.6  6315.24
# Trenton, NJ       16577.8     11608.7    16603.1      10133.1   1453.4
#
# name2       Evanston, WY Laramie, WY
# name
# Tucson, AZ       17613.6     14829.9
# Lansing, MI      7992.08     6005.59
# Bozeman, MT      11911.2     12467.1
# Reno, NV         14050.3     13070.8
# Trenton, NJ      11154.2     7793.74
#
# [5 rows x 148 columns]

# %% [markdown]
# ## Minimization

# %%
import pandas as pd
# !pip install pulp
from pulp import *
import numpy as np
# Out:
# Requirement already satisfied: pulp in c:\users\admin\anaconda3\lib\site-packages (2.4)
# Requirement already satisfied: amply>=0.1.2 in c:\users\admin\anaconda3\lib\site-packages (from pulp) (0.1.4)
# Requirement already satisfied: docutils>=0.3 in c:\users\admin\anaconda3\lib\site-packages (from amply>=0.1.2->pulp) (0.16)
# Requirement already satisfied: pyparsing in c:\users\admin\anaconda3\lib\site-packages (from amply>=0.1.2->pulp) (2.4.7)

# %%
Items =supply.Location.tolist()
Items
# Out:
# ['Tucson, AZ',
#  'Lansing, MI',
#  'Bozeman, MT',
#  'Reno, NV',
#  'Trenton, NJ',
#  'Columbus, OH',
#  'Harrisburg, PA',
#  'Florence, SC',
#  'Spokane, WA',
#  'Paris, TX',
#  'Louisville, KY']

# %%
supply_dict = supply.set_index('Location')['Supply'].to_dict()
supply_dict
# Out:
# {'Tucson, AZ': 2000.0,
#  'Lansing, MI': 2600.0,
#  'Bozeman, MT': 600.0,
#  'Reno, NV': 2500.0,
#  'Trenton, NJ': 3500.0,
#  'Columbus, OH': 2200.0,
#  'Harrisburg, PA': 2500.0,
#  'Florence, SC': 2500.0,
#  'Spokane, WA': 3000.0,
#  'Paris, TX': 5000.0,
#  'Louisville, KY': 5000.0}

# %%
Items1 =demand.Location.tolist()
Items1
# Out:
# ['Birmingham, AL',
#  'Mobile, AL',
#  'Montgomery, AL',
#  'Tuscaloosa, AL',
#  'Anchorage, AK',
#  'Fairbanks, AK',
#  'Juneau, AK',
#  'Flagstaff, AZ',
#  'Phoenix, AZ',
#  'Scottsdale, AZ',
#  'Winslow, AZ',
#  'Fayetteville, AR',
#  'Little Rock, AR',
#  'Texarkana, AR',
#  'Bakersfield, CA',
#  'Los Angeles, CA',
#  'Palm Springs, CA',
#  'Sacramento, CA',
#  'San Diego, CA',
#  'San Francisco, CA',
#  'Aspen, CO',
#  'Denver, CO',
#  'Danbury, CT',
#  'New Haven, CT',
#  'Wilmington, DE',
#  'Fort Lauderdale, FL',
#  'Gainesville, FL',
#  'Jacksonville, FL',
#  'Miami, FL',
#  'Orlando, FL',
#  'Panama City, FL',
#  'Tallahassee, FL',
#  'Tampa, FL',
#  'Athens-Clarke County, GA',
#  'Atlanta, GA',
#  'Columbus, GA',
#  'Savannah, GA',
#  'Honolulu, HI',
#  'Boise City, ID',
#  'Pocatello, ID',
#  'Chicago, IL',
#  'Peoria, IL',
#  'Bloomington, IN',
#  'Indianapolis, IN',
#  'Muncie, IN',
#  'Des Moines, IA',
#  'Topeka, KS',
#  'Wichita, KS',
#  'Louisville, KY',
#  'Paducah, KY',
#  'Baton Rouge, LA',
#  'New Orleans, LA',
#  'Shreveport, LA',
#  'Bangor, ME',
#  'Bar Harbor, ME',
#  'Portland, ME',
#  'Baltimore, MD',
#  'Ocean City, MD',
#  'Boston, MA',
#  'Ann Arbor, MI',
#  'Detroit, MI',
#  'Kalamazoo, MI',
#  'Ypsilanti, MI',
#  'Duluth, MN',
#  'Minneapolis, MN',
#  'Saint Paul, MN',
#  'Gulfport, MS',
#  'Jackson, MS',
#  'Tupelo, MS',
#  'Columbia, MO',
#  'Kansas City, MO',
#  'Springfield, MO',
#  'Billings, MT',
#  'Helena, MT',
#  'Missoula, MT',
#  'Lincoln, NE',
#  'Omaha, NE',
#  'Elko, NV',
#  'Las Vegas, NV',
#  'Concord, NH',
#  'Manchester, NH',
#  'Atlantic City, NJ',
#  'Hoboken, NJ',
#  'Newark, NJ',
#  'Albuquerque, NM',
#  'Santa Fe, NM',
#  'Binghamton, NY',
#  'Buffalo, NY',
#  'New York, NY',
#  'Syracuse, NY',
#  'Charlotte, NC',
#  'Raleigh, NC',
#  'Winston-Salem, NC',
#  'Bismarck, ND',
#  'Fargo, ND',
#  'Canton, OH',
#  'Cincinnati, OH',
#  'Cleveland, OH',
#  'Toledo, OH',
#  'Oklahoma City, OK',
#  'Eugene, OR',
#  'Portland, OR',
#  'Salem, OR',
#  'Altoona, PA',
#  'Philadelphia, PA',
#  'Reading, PA',
#  'Wilkes-Barre, PA',
#  'Providence, RI',
#  'Charleston, SC',
#  'Columbia, SC',
#  'Spartanburg, SC',
#  'Rapid City, SD',
#  'Sioux Falls, SD',
#  'Watertown, SD',
#  'Chattanooga, TN',
#  'Memphis, TN',
#  'Nashville-Davidson, TN',
#  'Brownsville, TX',
#  'Dallas, TX',
#  'El Paso, TX',
#  'Galveston, TX',
#  'Houston, TX',
#  'Lubbock, TX',
#  'Paris, TX',
#  'San Antonio, TX',
#  'Cedar City, UT',
#  'Moab, UT',
#  'Salt Lake City, UT',
#  'Montpelier, VT',
#  'Newport, VT',
#  'Newport News, VA',
#  'Richmond, VA',
#  'Olympia, WA',
#  'Seattle, WA',
#  'Tacoma, WA',
#  'Walla Walla, WA',
#  'Clarksburg, WV',
#  'Morgantown, WV',
#  'Wheeling, WV',
#  'Green Bay, WI',
#  'Madison, WI',
#  'Milwaukee, WI',
#  'Oshkosh, WI',
#  'Casper, WY',
#  'Cheyenne, WY',
#  'Cody, WY',
#  'Evanston, WY',
#  'Laramie, WY']

# %%
demand_dict = demand.set_index('Location')['Demand'].to_dict()
demand_dict
# Out:
# {'Birmingham, AL': 200,
#  'Mobile, AL': 100,
#  'Montgomery, AL': 150,
#  'Tuscaloosa, AL': 50,
#  'Anchorage, AK': 50,
#  'Fairbanks, AK': 100,
#  'Juneau, AK': 200,
#  'Flagstaff, AZ': 50,
#  'Phoenix, AZ': 300,
#  'Scottsdale, AZ': 100,
#  'Winslow, AZ': 50,
#  'Fayetteville, AR': 200,
#  'Little Rock, AR': 300,
#  'Texarkana, AR': 50,
#  'Bakersfield, CA': 50,
#  'Los Angeles, CA': 500,
#  'Palm Springs, CA': 100,
#  'Sacramento, CA': 200,
#  'San Diego, CA': 400,
#  'San Francisco, CA': 250,
#  'Aspen, CO': 100,
#  'Denver, CO': 250,
#  'Danbury, CT': 50,
#  'New Haven, CT': 100,
#  'Wilmington, DE': 250,
#  'Fort Lauderdale, FL': 150,
#  'Gainesville, FL': 100,
#  'Jacksonville, FL': 400,
#  'Miami, FL': 500,
#  'Orlando, FL': 450,
#  'Panama City, FL': 50,
#  'Tallahassee, FL': 150,
#  'Tampa, FL': 200,
#  'Athens-Clarke County, GA': 100,
#  'Atlanta, GA': 500,
#  'Columbus, GA': 150,
#  'Savannah, GA': 200,
#  'Honolulu, HI': 500,
#  'Boise City, ID': 150,
#  'Pocatello, ID': 50,
#  'Chicago, IL': 450,
#  'Peoria, IL': 150,
#  'Bloomington, IN': 100,
#  'Indianapolis, IN': 450,
#  'Muncie, IN': 150,
#  'Des Moines, IA': 250,
#  'Topeka, KS': 150,
#  'Wichita, KS': 50,
#  'Louisville, KY': 200,
#  'Paducah, KY': 50,
#  'Baton Rouge, LA': 300,
#  'New Orleans, LA': 350,
#  'Shreveport, LA': 100,
#  'Bangor, ME': 50,
#  'Bar Harbor, ME': 50,
#  'Portland, ME': 150,
#  'Baltimore, MD': 450,
#  'Ocean City, MD': 150,
#  'Boston, MA': 450,
#  'Ann Arbor, MI': 200,
#  'Detroit, MI': 500,
#  'Kalamazoo, MI': 50,
#  'Ypsilanti, MI': 50,
#  'Duluth, MN': 150,
#  'Minneapolis, MN': 300,
#  'Saint Paul, MN': 350,
#  'Gulfport, MS': 100,
#  'Jackson, MS': 50,
#  'Tupelo, MS': 100,
#  'Columbia, MO': 250,
#  'Kansas City, MO': 350,
#  'Springfield, MO': 150,
#  'Billings, MT': 150,
#  'Helena, MT': 100,
#  'Missoula, MT': 50,
#  'Lincoln, NE': 250,
#  'Omaha, NE': 300,
#  'Elko, NV': 100,
#  'Las Vegas, NV': 350,
#  'Concord, NH': 150,
#  'Manchester, NH': 100,
#  'Atlantic City, NJ': 250,
#  'Hoboken, NJ': 150,
#  'Newark, NJ': 350,
#  'Albuquerque, NM': 150,
#  'Santa Fe, NM': 150,
#  'Binghamton, NY': 250,
#  'Buffalo, NY': 350,
#  'New York, NY': 600,
#  'Syracuse, NY': 250,
#  'Charlotte, NC': 300,
#  'Raleigh, NC': 250,
#  'Winston-Salem, NC': 150,
#  'Bismarck, ND': 100,
#  'Fargo, ND': 50,
#  'Canton, OH': 100,
#  'Cincinnati, OH': 400,
#  'Cleveland, OH': 350,
#  'Toledo, OH': 100,
#  'Oklahoma City, OK': 150,
#  'Eugene, OR': 100,
#  'Portland, OR': 200,
#  'Salem, OR': 200,
#  'Altoona, PA': 50,
#  'Philadelphia, PA': 550,
#  'Reading, PA': 100,
#  'Wilkes-Barre, PA': 50,
#  'Providence, RI': 150,
#  'Charleston, SC': 200,
#  'Columbia, SC': 250,
#  'Spartanburg, SC': 50,
#  'Rapid City, SD': 100,
#  'Sioux Falls, SD': 150,
#  'Watertown, SD': 50,
#  'Chattanooga, TN': 150,
#  'Memphis, TN': 250,
#  'Nashville-Davidson, TN': 200,
#  'Brownsville, TX': 50,
#  'Dallas, TX': 450,
#  'El Paso, TX': 150,
#  'Galveston, TX': 100,
#  'Houston, TX': 350,
#  'Lubbock, TX': 50,
#  'Paris, TX': 50,
#  'San Antonio, TX': 250,
#  'Cedar City, UT': 100,
#  'Moab, UT': 50,
#  'Salt Lake City, UT': 350,
#  'Montpelier, VT': 100,
#  'Newport, VT': 100,
#  'Newport News, VA': 150,
#  'Richmond, VA': 300,
#  'Olympia, WA': 350,
#  'Seattle, WA': 250,
#  'Tacoma, WA': 100,
#  'Walla Walla, WA': 50,
#  'Clarksburg, WV': 100,
#  'Morgantown, WV': 150,
#  'Wheeling, WV': 150,
#  'Green Bay, WI': 150,
#  'Madison, WI': 250,
#  'Milwaukee, WI': 300,
#  'Oshkosh, WI': 50,
#  'Casper, WY': 50,
#  'Cheyenne, WY': 150,
#  'Cody, WY': 50,
#  'Evanston, WY': 150,
#  'Laramie, WY': 100}

# %%
# Setting up the Problem 
prob = LpProblem("Transportation", LpMinimize)

# %%
# Creates a list of tuples containing all the possible routes for transport
Routes = [(w,b) for w in Items for b in Items1]

# %%
route_vars = LpVariable.dicts("Route",(Items,Items1),0)

# %%
prob += lpSum([route_vars[w][b]*new_cost_df.loc[w,b] for (w,b) in Routes])

# %%
for w in Items:
    prob += lpSum([route_vars[w][b] for b in Items1]) <= supply_dict[w], "Sum of Products out of Warehouse %s"%w

# The demand minimum constraints are added to prob for each demand node (bar)
for b in Items1:
    prob += lpSum([route_vars[w][b] for w in Items]) >= demand_dict[b], "Sum of Products into Bars %s"%b

# %%
prob.solve()
# Out:
# 1

# %%
print("Status:", LpStatus[prob.status])
# Out:
# Status: Optimal

# %%
for v in prob.variables():
    if v.varValue > 0:
        print(v.name, "=", v.varValue)
# Out:
# Route_Bozeman,_MT_Denver,_CO = 250.0
# Route_Bozeman,_MT_Indianapolis,_IN = 350.0
# Route_Columbus,_OH_Tacoma,_WA = 100.0
# Route_Florence,_SC_Chattanooga,_TN = 100.0
# Route_Florence,_SC_Cheyenne,_WY = 150.0
# Route_Florence,_SC_Duluth,_MN = 150.0
# Route_Florence,_SC_Hoboken,_NJ = 150.0
# Route_Florence,_SC_Laramie,_WY = 100.0
# Route_Florence,_SC_Little_Rock,_AR = 300.0
# Route_Florence,_SC_Muncie,_IN = 150.0
# Route_Florence,_SC_New_York,_NY = 600.0
# Route_Florence,_SC_Newark,_NJ = 250.0
# Route_Florence,_SC_Olympia,_WA = 350.0
# Route_Florence,_SC_Oshkosh,_WI = 50.0
# Route_Florence,_SC_Portland,_ME = 150.0
# Route_Harrisburg,_PA_Athens_Clarke_County,_GA = 100.0
# Route_Harrisburg,_PA_Bar_Harbor,_ME = 50.0
# Route_Harrisburg,_PA_Casper,_WY = 50.0
# Route_Harrisburg,_PA_Elko,_NV = 100.0
# Route_Harrisburg,_PA_Fargo,_ND = 50.0
# Route_Harrisburg,_PA_Lincoln,_NE = 250.0
# Route_Harrisburg,_PA_Memphis,_TN = 250.0
# Route_Harrisburg,_PA_Miami,_FL = 500.0
# Route_Harrisburg,_PA_Omaha,_NE = 300.0
# Route_Harrisburg,_PA_Peoria,_IL = 150.0
# Route_Harrisburg,_PA_Pocatello,_ID = 50.0
# Route_Harrisburg,_PA_Providence,_RI = 150.0
# Route_Harrisburg,_PA_Seattle,_WA = 250.0
# Route_Harrisburg,_PA_Springfield,_MO = 150.0
# Route_Harrisburg,_PA_Toledo,_OH = 100.0
# Route_Lansing,_MI_Anchorage,_AK = 50.0
# Route_Lansing,_MI_Boston,_MA = 450.0
# Route_Lansing,_MI_Detroit,_MI = 500.0
# Route_Lansing,_MI_Fayetteville,_AR = 200.0
# Route_Lansing,_MI_Houston,_TX = 350.0
# Route_Lansing,_MI_Las_Vegas,_NV = 350.0
# Route_Lansing,_MI_Nashville_Davidson,_TN = 200.0
# Route_Lansing,_MI_New_Orleans,_LA = 350.0
# Route_Lansing,_MI_Winston_Salem,_NC = 150.0
# Route_Louisville,_KY_Albuquerque,_NM = 150.0
# Route_Louisville,_KY_Ann_Arbor,_MI = 200.0
# Route_Louisville,_KY_Bakersfield,_CA = 50.0
# Route_Louisville,_KY_Baton_Rouge,_LA = 300.0
# Route_Louisville,_KY_Binghamton,_NY = 250.0
# Route_Louisville,_KY_Bismarck,_ND = 100.0
# Route_Louisville,_KY_Boise_City,_ID = 150.0
# Route_Louisville,_KY_Buffalo,_NY = 350.0
# Route_Louisville,_KY_Chicago,_IL = 450.0
# Route_Louisville,_KY_Cleveland,_OH = 350.0
# Route_Louisville,_KY_Eugene,_OR = 100.0
# Route_Louisville,_KY_Gainesville,_FL = 100.0
# Route_Louisville,_KY_Galveston,_TX = 100.0
# Route_Louisville,_KY_Louisville,_KY = 200.0
# Route_Louisville,_KY_Missoula,_MT = 50.0
# Route_Louisville,_KY_Montpelier,_VT = 100.0
# Route_Louisville,_KY_Orlando,_FL = 450.0
# Route_Louisville,_KY_Panama_City,_FL = 50.0
# Route_Louisville,_KY_Reading,_PA = 100.0
# Route_Louisville,_KY_San_Francisco,_CA = 250.0
# Route_Louisville,_KY_Spartanburg,_SC = 50.0
# Route_Louisville,_KY_Tallahassee,_FL = 150.0
# Route_Louisville,_KY_Tampa,_FL = 200.0
# Route_Louisville,_KY_Tupelo,_MS = 100.0
# Route_Louisville,_KY_Wichita,_KS = 50.0
# Route_Louisville,_KY_Wilkes_Barre,_PA = 50.0
# Route_Louisville,_KY_Ypsilanti,_MI = 50.0
# Route_Paris,_TX_Altoona,_PA = 50.0
# Route_Paris,_TX_Aspen,_CO = 100.0
# Route_Paris,_TX_Atlanta,_GA = 500.0
# Route_Paris,_TX_Baltimore,_MD = 150.0
# Route_Paris,_TX_Bangor,_ME = 50.0
# Route_Paris,_TX_Billings,_MT = 150.0
# Route_Paris,_TX_Bloomington,_IN = 100.0
# Route_Paris,_TX_Cedar_City,_UT = 100.0
# Route_Paris,_TX_Charleston,_SC = 200.0
# Route_Paris,_TX_Columbia,_MO = 250.0
# Route_Paris,_TX_El_Paso,_TX = 150.0
# Route_Paris,_TX_Fairbanks,_AK = 100.0
# Route_Paris,_TX_Fort_Lauderdale,_FL = 150.0
# Route_Paris,_TX_Green_Bay,_WI = 150.0
# Route_Paris,_TX_Juneau,_AK = 200.0
# Route_Paris,_TX_Kansas_City,_MO = 350.0
# Route_Paris,_TX_Lubbock,_TX = 50.0
# Route_Paris,_TX_Minneapolis,_MN = 300.0
# Route_Paris,_TX_Montgomery,_AL = 150.0
# Route_Paris,_TX_Ocean_City,_MD = 150.0
# Route_Paris,_TX_Palm_Springs,_CA = 100.0
# Route_Paris,_TX_Paris,_TX = 50.0
# Route_Paris,_TX_Saint_Paul,_MN = 350.0
# Route_Paris,_TX_San_Diego,_CA = 400.0
# Route_Paris,_TX_Savannah,_GA = 200.0
# Route_Paris,_TX_Shreveport,_LA = 100.0
# Route_Reno,_NV_Atlantic_City,_NJ = 250.0
# Route_Reno,_NV_Baltimore,_MD = 300.0
# Route_Reno,_NV_Birmingham,_AL = 200.0
# Route_Reno,_NV_Cincinnati,_OH = 400.0
# Route_Reno,_NV_Clarksburg,_WV = 100.0
# Route_Reno,_NV_Dallas,_TX = 450.0
# Route_Reno,_NV_Indianapolis,_IN = 100.0
# Route_Reno,_NV_Morgantown,_WV = 150.0
# Route_Reno,_NV_Phoenix,_AZ = 50.0
# Route_Reno,_NV_Portland,_OR = 200.0
# Route_Reno,_NV_Texarkana,_AR = 50.0
# Route_Reno,_NV_Topeka,_KS = 150.0
# Route_Reno,_NV_Tuscaloosa,_AL = 50.0
# Route_Reno,_NV_Walla_Walla,_WA = 50.0
# Route_Spokane,_WA_Chattanooga,_TN = 50.0
# Route_Spokane,_WA_Danbury,_CT = 50.0
# Route_Spokane,_WA_Evanston,_WY = 150.0
# Route_Spokane,_WA_Flagstaff,_AZ = 50.0
# Route_Spokane,_WA_Gulfport,_MS = 100.0
# Route_Spokane,_WA_Jacksonville,_FL = 400.0
# Route_Spokane,_WA_Kalamazoo,_MI = 50.0
# Route_Spokane,_WA_Madison,_WI = 250.0
# Route_Spokane,_WA_Manchester,_NH = 100.0
# Route_Spokane,_WA_Milwaukee,_WI = 300.0
# Route_Spokane,_WA_Mobile,_AL = 100.0
# Route_Spokane,_WA_New_Haven,_CT = 100.0
# Route_Spokane,_WA_Newport_News,_VA = 150.0
# Route_Spokane,_WA_Oklahoma_City,_OK = 150.0
# Route_Spokane,_WA_Paducah,_KY = 50.0
# Route_Spokane,_WA_Raleigh,_NC = 250.0
# Route_Spokane,_WA_San_Antonio,_TX = 250.0
# Route_Spokane,_WA_Santa_Fe,_NM = 150.0
# Route_Spokane,_WA_Syracuse,_NY = 250.0
# Route_Spokane,_WA_Winslow,_AZ = 50.0
# Route_Trenton,_NJ_Canton,_OH = 100.0
# Route_Trenton,_NJ_Charlotte,_NC = 300.0
# Route_Trenton,_NJ_Cody,_WY = 50.0
# Route_Trenton,_NJ_Columbia,_SC = 250.0
# Route_Trenton,_NJ_Concord,_NH = 150.0
# Route_Trenton,_NJ_Des_Moines,_IA = 250.0
# Route_Trenton,_NJ_Helena,_MT = 100.0
# Route_Trenton,_NJ_Jackson,_MS = 50.0
# Route_Trenton,_NJ_Los_Angeles,_CA = 500.0
# Route_Trenton,_NJ_Moab,_UT = 50.0
# Route_Trenton,_NJ_Newark,_NJ = 100.0
# Route_Trenton,_NJ_Phoenix,_AZ = 250.0
# Route_Trenton,_NJ_Rapid_City,_SD = 100.0
# Route_Trenton,_NJ_Richmond,_VA = 300.0
# Route_Trenton,_NJ_Sacramento,_CA = 200.0
# Route_Trenton,_NJ_Salt_Lake_City,_UT = 350.0
# Route_Trenton,_NJ_Scottsdale,_AZ = 100.0
# Route_Trenton,_NJ_Sioux_Falls,_SD = 150.0
# Route_Trenton,_NJ_Wheeling,_WV = 150.0
# Route_Tucson,_AZ_Brownsville,_TX = 50.0
# Route_Tucson,_AZ_Columbus,_GA = 150.0
# Route_Tucson,_AZ_Honolulu,_HI = 500.0
# Route_Tucson,_AZ_Newport,_VT = 100.0
# Route_Tucson,_AZ_Philadelphia,_PA = 550.0
# Route_Tucson,_AZ_Salem,_OR = 200.0
# Route_Tucson,_AZ_Watertown,_SD = 50.0
# Route_Tucson,_AZ_Wilmington,_DE = 250.0

# %%
print("Total transportation cost = ", value(prob.objective))
# Out:
# Total transportation cost =  131056784.63533074
